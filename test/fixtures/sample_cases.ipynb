# %% [markdown]
# # Sample cases
# Do not modify this markdown cell.

# %%
def transform(df):
    return spark.table('t').where((F.col('a') == 1) | (F.col('b') == 2)).select(F.col('a'), F.col('b'))

# %%
df.filter((F.col('a') == 1) & (F.col('b') == 2) | (F.col('c') == 3))
