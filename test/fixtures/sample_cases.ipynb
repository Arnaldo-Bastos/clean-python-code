# %% [markdown]
# # Sample cases
# Do not modify this markdown cell.

# %%
def build_df():
    return spark.table('t').where((F.col('a') == 1) | (F.col('b') == 2))

# %%
df = spark.table('t').filter((F.col('a') == 1) & (F.col('b') == 2) | (F.col('c') == 3))
